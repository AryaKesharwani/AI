# %%
# Importing the necessary libraries
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Ensure the VADER lexicon is downloaded
nltk.download('vader_lexicon')

# Create a SentimentIntensityAnalyzer object
sia = SentimentIntensityAnalyzer()

# List of sample texts
texts = ["NLTK is an amazing library for natural language processing!",
         "I love this product!",
         "This is a terrible mistake.",
         "I feel nothing about this."]

# Analyze the sentiment of each text
for text in texts:
    # Get the sentiment scores
    sentiment_scores = sia.polarity_scores(text)
    # Print the results
    print(f'Text: {text}\nScores: {sentiment_scores}\n')
# Out:
# Text: NLTK is an amazing library for natural language processing!
# Scores: {'neg': 0.0, 'neu': 0.515, 'pos': 0.485, 'compound': 0.7644}
#
# Text: I love this product!
# Scores: {'neg': 0.0, 'neu': 0.308, 'pos': 0.692, 'compound': 0.6696}
#
# Text: This is a terrible mistake.
# Scores: {'neg': 0.733, 'neu': 0.267, 'pos': 0.0, 'compound': -0.6705}
#
# Text: I feel nothing about this.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
